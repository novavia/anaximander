# %%
import anaximander as nx
from anaximander.projects import Project

dataforge_path = nx.REPO / "tests/projects/dataforge"
source_prototypes = nx.REPO / "tests/testdata/prototypes/dataforge"
compilation_targets = nx.REPO / "tests/testdata/compilation_targets/dataforge"

# %%
if Project.is_project_directory(dataforge_path):
    dataforge_project = Project(dataforge_path)
else:
    dataforge_project = Project.create("dataforge", parent_directory=dataforge_path.parent, prototypes=source_prototypes)

# %%
dataforge_project.compile("sqlalchemy")
